# %%
import pandas as pd

# %%
aisles = pd.read_csv('aisles.csv')
departments = pd.read_csv('departments.csv')
order_products_prior = pd.read_csv('order_products__prior.csv')
order_products_train = pd.read_csv('order_products__train.csv')
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')

# %%
dfs = {
    'aisles': aisles,
    'departments': departments,
    'order_products_prior': order_products_prior,
    'order_products_train': order_products_train,
    'orders': orders,
    'products': products
}
for name, df in dfs.items():
    print(f'\n {name}: {df.shape}')
    print(df.head(5))
    print(f"\ncolumns: {df.columns.tolist()}")
    print(f"===============================================================================================================================================================================")
# Out:
#  aisles: (134, 2)
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
#
# columns: ['aisle_id', 'aisle']
# ...
#
#  departments: (21, 2)
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol
#
# columns: ['department_id', 'department']
# ...
#
#  order_products_prior: (32434489, 4)
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0
#
# ...

# %%
orders.eval_set.value_counts()
# Out:
# eval_set
# prior    3214874
# train     131209
# test       75000
# Name: count, dtype: int64

# %%
order_products_prior.reordered.value_counts()
# Out:
# reordered
# 1    19126536
# 0    13307953
# Name: count, dtype: int64

# %%
order_products_train.reordered.value_counts()
# Out:
# reordered
# 1    828824
# 0    555793
# Name: count, dtype: int64

# %%
order_products_prior[(~order_products_prior.order_id .isin( order_products_train.order_id)) &
                       (~order_products_prior.product_id.isin(order_products_train.product_id))].order_id.nunique()
# Out:
# 150868

# %%
prior_pairs = set(zip(order_products_prior.order_id, order_products_prior.product_id))
train_pairs = set(zip(order_products_train.order_id, order_products_train.product_id))

len(prior_pairs.intersection(train_pairs))
# Out:
# 0

# %%
missing_prior = set(order_products_prior.order_id) - set(orders.order_id)
len(missing_prior)
# Out:
# 0

# %%
missing_train = set(order_products_train.order_id) - set(orders.order_id)
len(missing_train)
# Out:
# 0

# %%
test = orders[orders.eval_set == 'test']

# %%
test.head()
# Out:
#      order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 38    2774568        3     test            13          5                 15
# 44     329954        4     test             6          3                 12
# 53    1528013        6     test             4          3                 16
# 96    1376945       11     test             8          6                 11
# 102   1356845       12     test             6          1                 20
#
#      days_since_prior_order
# 38                     11.0
# 44                     30.0
# 53                     22.0
# 96                      8.0
# 102                    30.0

# %%
train = orders[orders.eval_set == 'train'].merge(order_products_train, on='order_id', how='left')

# %%
train.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   1187899        1    train            11          4                  8
# 1   1187899        1    train            11          4                  8
# 2   1187899        1    train            11          4                  8
# 3   1187899        1    train            11          4                  8
# 4   1187899        1    train            11          4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                    14.0         196                  1          1
# 1                    14.0       25133                  2          1
# 2                    14.0       38928                  3          1
# 3                    14.0       26405                  4          1
# 4                    14.0       39657                  5          1

# %%
len(set(train.order_number)-set(test.order_number))
# Out:
# 0
